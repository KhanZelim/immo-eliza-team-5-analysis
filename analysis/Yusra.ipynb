# %%
import pandas as pd
import matplotlib.pyplot as plt 

import csv

# %%
df = pd.read_csv("../data/cleaned/properties.csv")
properties =df

# %%
#1.How many observations and features do you have?

# %%
# Get the number of observations and features after clean the data.
observations, features = properties.shape

print(f'Number of observations (rows): {observations}')
print(f'Number of features (columns): {features}')
# Out:
# Number of observations (rows): 20758
# Number of features (columns): 21

# %%
#1.How many observations and features do you have?
#Before Data cleaing 
# #Number of  (rows): 75511
# Number of (columns): 30


#After Data cleaing 
#Number of (rows): 20758
#Number of (columns): 21

# %%
#observations 

properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   price                           20758 non-null  float64
#  2   property_type                   20758 non-null  object
#  3   subproperty_type                20758 non-null  object
#  4   region                          20758 non-null  object
#  5   province                        20758 non-null  object
#  6   locality                        20758 non-null  object
#  7   zip_code                        20758 non-null  int64
#  8   construction_year               20758 non-null  int64
#  9   total_area_sqm                  20758 non-null  float64
#  10  nbr_bedrooms                    20758 non-null  int64
#  11  equipped_kitchen                20758 non-null  object
# ...

# %%
#observations 

properties.shape
# Out:
# (20758, 21)

# %%
#observations 
# Displays the first 5 rows

properties.head(10)
# Out:
#          id      price property_type subproperty_type            region  \
# 0  34221000   225000.0     APARTMENT        APARTMENT          Flanders
# 1  58496000   501000.0         HOUSE            HOUSE          Flanders
# 2  48727000   982700.0     APARTMENT           DUPLEX          Wallonia
# 3  58028000  3500000.0         HOUSE            VILLA          Flanders
# 4  10079000   549000.0         HOUSE            VILLA          Flanders
# 5  33039000   175000.0     APARTMENT      FLAT_STUDIO  Brussels-Capital
# 6  15128000   130000.0     APARTMENT     GROUND_FLOOR          Flanders
# 7  34389000   165000.0         HOUSE            HOUSE          Wallonia
# 8  43150000   320844.0     APARTMENT        APARTMENT          Flanders
# 9  77787000   300000.0         HOUSE            HOUSE          Flanders
#
#           province     locality  zip_code  construction_year  total_area_sqm  \
# 0          Antwerp      Antwerp      2050               1963           100.0
# ...

# %%
# Displays the last 5 rows
properties.tail()
# Out:
#              id     price property_type subproperty_type    region  \
# 20753    630000  235000.0     APARTMENT        APARTMENT  Flanders
# 20754  36688000  265000.0         HOUSE            HOUSE  Wallonia
# 20755  67748000  255000.0     APARTMENT        APARTMENT  Flanders
# 20756  57381000  285000.0     APARTMENT        APARTMENT  Flanders
# 20757  22018000  199000.0     APARTMENT        APARTMENT  Wallonia
#
#               province         locality  zip_code  construction_year  \
# 20753  Flemish Brabant  Halle-Vilvoorde      1800               1937
# 20754            Liège          Waremme      4280               1900
# 20755          Antwerp          Antwerp      2600               1979
# 20756          Limburg          Hasselt      3580               2013
# 20757            Liège            Liège      4100               2008
#
#        total_area_sqm  ...  equipped_kitchen fl_furnished  fl_open_fire  \
# ...

# %%
df = pd.read_csv("../data/cleaned/properties.csv")
properties =df
properties[['price']].describe()
# Out:
#               price
# count  2.075800e+04
# mean   4.517904e+05
# std    4.686182e+05
# min    7.700000e+04
# 25%    2.399000e+05
# 50%    3.300000e+05
# 75%    4.890000e+05
# max    1.145000e+07

# %%
import pygwalker as pyg
df = pd.read_csv("../data/cleaned/properties.csv")
properties =df
walker=pyg.walk(properties)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-0006251178afb4bdsVGYt0lDPiR32mdH" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "0006251178afb4bdsVGYt0lDPiR32mdH") {
#             var iframe = document.getElementById("gwalker-0006251178afb4bdsVGYt0lDPiR32mdH");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
data = pd.read_csv("../data/cleaned/properties.csv")

# Count the number of houses per region
counts = data['region'].value_counts()  # Replace 'region_column_name' with the name of your region column

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Houses Percentage for sale in Brussels, Flanders and Wallonia')
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import csv 

df = pd.read_csv("../data/cleaned/properties.csv")
properties =df


plt.figure(figsize=(10, 6))
sns.boxplot(x='locality', y='price', data=properties)
plt.xlabel('locality')
plt.ylabel('Price')
plt.title(' Prices  by locality')
plt.xticks(rotation=80)
plt.show()

# %%
#type of properties for sale and rent in region

sns.countplot(x="property_type",hue="region",data=properties,palette='pink')
# Out:
# <Axes: xlabel='property_type', ylabel='count'>

# %%
# Data file before cleaning
#3-Which variables would you delete and why?

#Surface_land,br_frontages,fl_terrace,fl_garden, epc,heating_type, latitude, longitude, cadastral_income.

#variables with a high percentage of missing values (e.g., more than 50%), it might not be worth keeping



properties = pd.read_csv("data/raw/properties.csv")
#proportion of missing values per column

properties.columns
# Out:
# Index(['id', 'price', 'property_type', 'subproperty_type', 'region',
#        'province', 'locality', 'zip_code', 'latitude', 'longitude',
#        'construction_year', 'total_area_sqm', 'surface_land_sqm',
#        'nbr_frontages', 'nbr_bedrooms', 'equipped_kitchen', 'fl_furnished',
#        'fl_open_fire', 'fl_terrace', 'terrace_sqm', 'fl_garden', 'garden_sqm',
#        'fl_swimming_pool', 'fl_floodzone', 'state_building',
#        'primary_energy_consumption_sqm', 'epc', 'heating_type',
#        'fl_double_glazing', 'cadastral_income'],
#       dtype='object')

# %%
observations, features = properties.shape

print(f'Number of observations (rows): {observations}')
print(f'Number of features (columns): {features}')
# Out:
# Number of observations (rows): 75511
# Number of features (columns): 30

# %%
#Exploring the Features (columns) to understand their characteristics)
properties.columns
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75511 entries, 0 to 75510
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              75511 non-null  int64
#  1   price                           75511 non-null  float64
#  2   property_type                   75511 non-null  object
#  3   subproperty_type                75511 non-null  object
#  4   region                          75511 non-null  object
#  5   province                        75511 non-null  object
#  6   locality                        75511 non-null  object
#  7   zip_code                        75511 non-null  int64
#  8   latitude                        61413 non-null  float64
#  9   longitude                       61413 non-null  float64
#  10  construction_year               42120 non-null  float64
#  11  total_area_sqm                  67896 non-null  float64
# ...

# %%
#2-What is the proportion of missing values per column

# %%
#The proportion of missing values per column
properties = pd.read_csv("data/raw/properties.csv")
# Calculate the proportion of missing values per column
missing_proportion = properties.isnull().mean()

# Display the result as a percentage
missing_percentage = missing_proportion * 100
print(missing_percentage)
# Out:
# id                                 0.000000
# price                              0.000000
# property_type                      0.000000
# subproperty_type                   0.000000
# region                             0.000000
# province                           0.000000
# locality                           0.000000
# zip_code                           0.000000
# latitude                          18.670128
# longitude                         18.670128
# construction_year                 44.220047
# total_area_sqm                    10.084623
# surface_land_sqm                  48.014197
# nbr_frontages                     34.890281
# nbr_bedrooms                       0.000000
# equipped_kitchen                   0.000000
# fl_furnished                       0.000000
# fl_open_fire                       0.000000
# fl_terrace                         0.000000
# terrace_sqm                       17.401438
# fl_garden                          0.000000
# ...

# %%
#3-Which variables would you delete and why?
#Surface_land,br_frontages,fl_terrace,fl_garden, epc,heating_type, latitude, longitude, cadastral_income.

#this variables have a high percentage of missing values (e.g., more than 50%), it might not be worth keeping

# %%
#Columns we will delete it are 
properties = properties.drop(columns=["nbr_frontages", "surface_land_sqm", 
                                      "fl_terrace", "fl_garden", "epc", 
                                      "heating_type", "latitude", "longitude", "cadastral_income"], axis=1)

# %%
properties = properties.dropna()
properties.head()
# Out:
#           id      price property_type subproperty_type    region  \
# 0   34221000   225000.0     APARTMENT        APARTMENT  Flanders
# 3   58496000   501000.0         HOUSE            HOUSE  Flanders
# 4   48727000   982700.0     APARTMENT           DUPLEX  Wallonia
# 9   58028000  3500000.0         HOUSE            VILLA  Flanders
# 20  10079000   549000.0         HOUSE            VILLA  Flanders
#
#            province     locality  zip_code  construction_year  total_area_sqm  \
# 0           Antwerp      Antwerp      2050             1963.0           100.0
# 3           Antwerp     Turnhout      2275             2024.0           187.0
# 4   Walloon Brabant     Nivelles      1410             2022.0           169.0
# 9     West Flanders       Brugge      8300             1935.0           277.0
# 20    East Flanders  Dendermonde      9240             2001.0           185.0
#
#     ...  equipped_kitchen fl_furnished  fl_open_fire  terrace_sqm  garden_sqm  \
# ...
